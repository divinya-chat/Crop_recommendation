# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Load the dataset
data = pd.read_csv('Crop_recommendation.csv')

# Extract features and labels
features = data.iloc[:, :-1].values
labels = data.iloc[:, -1].values

# Use LabelEncoder to convert string labels to numerical labels
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# Normalize features
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler on the training features
features_scaled = scaler.fit_transform(features)
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    features_scaled, labels_encoded, test_size=0.2, random_state=42)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# Build LSTM Model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True,
          input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=50))
model.add(Dense(units=len(np.unique(labels)), activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32,
          validation_data=(X_test, y_test))

# Example new data point for prediction with 6 features
# Replace with your actual values
new_data_point = np.array([[80, 50, 42, 22.5, 75.0, 6.8, 3]])

# Normalize the new data using the fitted scaler
new_data_scaled = scaler.transform(new_data_point)

# Reshape the new data for LSTM input
new_data_reshaped = np.reshape(
    new_data_scaled, (1, 1, new_data_scaled.shape[1]))

# Make prediction
prediction = model.predict(new_data_reshaped)

# Decode the predicted label
predicted_label = label_encoder.inverse_transform([np.argmax(prediction)])

print("Predicted Crop:", predicted_label[0])
# Out:
# Epoch 1/50
# 55/55 [==============================] - 5s 19ms/step - loss: 3.0848 - accuracy: 0.0983 - val_loss: 3.0744 - val_accuracy: 0.1773
# Epoch 2/50
# 55/55 [==============================] - 0s 3ms/step - loss: 3.0279 - accuracy: 0.1517 - val_loss: 2.9441 - val_accuracy: 0.1182
# Epoch 3/50
# 55/55 [==============================] - 0s 3ms/step - loss: 2.7044 - accuracy: 0.1977 - val_loss: 2.4271 - val_accuracy: 0.2659
# Epoch 4/50
# 55/55 [==============================] - 0s 4ms/step - loss: 2.0507 - accuracy: 0.4744 - val_loss: 1.6842 - val_accuracy: 0.6386
# Epoch 5/50
# 55/55 [==============================] - 0s 3ms/step - loss: 1.4040 - accuracy: 0.6858 - val_loss: 1.2017 - val_accuracy: 0.7295
# Epoch 6/50
# 55/55 [==============================] - 0s 4ms/step - loss: 1.0434 - accuracy: 0.7955 - val_loss: 0.9541 - val_accuracy: 0.7909
# Epoch 7/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.8418 - accuracy: 0.8307 - val_loss: 0.8199 - val_accuracy: 0.7545
# Epoch 8/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.7099 - accuracy: 0.8710 - val_loss: 0.7061 - val_accuracy: 0.8341
# Epoch 9/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.6138 - accuracy: 0.8778 - val_loss: 0.6143 - val_accuracy: 0.8705
# Epoch 10/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.5376 - accuracy: 0.9136 - val_loss: 0.5454 - val_accuracy: 0.8886
# Epoch 11/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.4776 - accuracy: 0.9142 - val_loss: 0.5007 - val_accuracy: 0.8955
# Epoch 12/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.4279 - accuracy: 0.9250 - val_loss: 0.4489 - val_accuracy: 0.8932
# Epoch 13/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.3877 - accuracy: 0.9273 - val_loss: 0.4130 - val_accuracy: 0.9045
# Epoch 14/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.3548 - accuracy: 0.9415 - val_loss: 0.3804 - val_accuracy: 0.9136
# Epoch 15/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.3221 - accuracy: 0.9477 - val_loss: 0.3613 - val_accuracy: 0.9136
# Epoch 16/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.2983 - accuracy: 0.9466 - val_loss: 0.3365 - val_accuracy: 0.9182
# Epoch 17/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.2780 - accuracy: 0.9483 - val_loss: 0.3087 - val_accuracy: 0.9318
# Epoch 18/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.2592 - accuracy: 0.9534 - val_loss: 0.2870 - val_accuracy: 0.9386
# Epoch 19/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.2421 - accuracy: 0.9585 - val_loss: 0.2751 - val_accuracy: 0.9477
# Epoch 20/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.2252 - accuracy: 0.9642 - val_loss: 0.2624 - val_accuracy: 0.9364
# Epoch 21/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.2118 - accuracy: 0.9625 - val_loss: 0.2495 - val_accuracy: 0.9432
# Epoch 22/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.2022 - accuracy: 0.9648 - val_loss: 0.2336 - val_accuracy: 0.9455
# Epoch 23/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1912 - accuracy: 0.9653 - val_loss: 0.2313 - val_accuracy: 0.9432
# Epoch 24/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1827 - accuracy: 0.9636 - val_loss: 0.2177 - val_accuracy: 0.9455
# Epoch 25/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1708 - accuracy: 0.9659 - val_loss: 0.2083 - val_accuracy: 0.9523
# Epoch 26/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1636 - accuracy: 0.9693 - val_loss: 0.1987 - val_accuracy: 0.9500
# Epoch 27/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1561 - accuracy: 0.9710 - val_loss: 0.1974 - val_accuracy: 0.9523
# Epoch 28/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1502 - accuracy: 0.9727 - val_loss: 0.1902 - val_accuracy: 0.9477
# Epoch 29/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1417 - accuracy: 0.9710 - val_loss: 0.1893 - val_accuracy: 0.9500
# Epoch 30/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1384 - accuracy: 0.9699 - val_loss: 0.1747 - val_accuracy: 0.9568
# Epoch 31/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1315 - accuracy: 0.9727 - val_loss: 0.1786 - val_accuracy: 0.9523
# Epoch 32/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1267 - accuracy: 0.9750 - val_loss: 0.1707 - val_accuracy: 0.9477
# Epoch 33/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1200 - accuracy: 0.9773 - val_loss: 0.1637 - val_accuracy: 0.9500
# Epoch 34/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.1176 - accuracy: 0.9756 - val_loss: 0.1595 - val_accuracy: 0.9568
# Epoch 35/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.1143 - accuracy: 0.9807 - val_loss: 0.1595 - val_accuracy: 0.9500
# Epoch 36/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1100 - accuracy: 0.9767 - val_loss: 0.1504 - val_accuracy: 0.9545
# Epoch 37/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1063 - accuracy: 0.9784 - val_loss: 0.1670 - val_accuracy: 0.9500
# Epoch 38/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.1032 - accuracy: 0.9761 - val_loss: 0.1472 - val_accuracy: 0.9523
# Epoch 39/50
# 55/55 [==============================] - 0s 7ms/step - loss: 0.1006 - accuracy: 0.9801 - val_loss: 0.1472 - val_accuracy: 0.9614
# Epoch 40/50
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0957 - accuracy: 0.9835 - val_loss: 0.1474 - val_accuracy: 0.9591
# Epoch 41/50
# 55/55 [==============================] - 1s 13ms/step - loss: 0.0935 - accuracy: 0.9835 - val_loss: 0.1438 - val_accuracy: 0.9591
# Epoch 42/50
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0918 - accuracy: 0.9807 - val_loss: 0.1362 - val_accuracy: 0.9591
# Epoch 43/50
# 55/55 [==============================] - 0s 9ms/step - loss: 0.0910 - accuracy: 0.9795 - val_loss: 0.1353 - val_accuracy: 0.9636
# Epoch 44/50
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0872 - accuracy: 0.9784 - val_loss: 0.1392 - val_accuracy: 0.9568
# Epoch 45/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0839 - accuracy: 0.9835 - val_loss: 0.1309 - val_accuracy: 0.9568
# Epoch 46/50
# 55/55 [==============================] - 0s 6ms/step - loss: 0.0810 - accuracy: 0.9835 - val_loss: 0.1267 - val_accuracy: 0.9614
# Epoch 47/50
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0814 - accuracy: 0.9818 - val_loss: 0.1273 - val_accuracy: 0.9591
# Epoch 48/50
# 55/55 [==============================] - 0s 8ms/step - loss: 0.0800 - accuracy: 0.9835 - val_loss: 0.1307 - val_accuracy: 0.9591
# Epoch 49/50
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0755 - accuracy: 0.9847 - val_loss: 0.1234 - val_accuracy: 0.9568
# Epoch 50/50
# 55/55 [==============================] - 0s 7ms/step - loss: 0.0757 - accuracy: 0.9847 - val_loss: 0.1239 - val_accuracy: 0.9614
# 1/1 [==============================] - 1s 1s/step
# Predicted Crop: muskmelon

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense

# Load the dataset
data = pd.read_csv('Crop_recommendation.csv')

# Extract features and labels
features = data.iloc[:, :-1].values
labels = data.iloc[:, -1].values

# Use LabelEncoder to convert string labels to numerical labels
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# Normalize features
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler on the training features
features_scaled = scaler.fit_transform(features)

# %%
from keras.models import load_model

# Save the model
# model.save('your_lstm_model.h5')

# Load the model
loaded_model = load_model('your_lstm_model.h5')

# Example new data point for prediction with 6 features
# Replace with your actual values
new_data_point = np.array([[80, 50, 42, 22.5, 75.0, 6.8, 3]])

# Normalize the new data using the fitted scaler
new_data_scaled = scaler.transform(new_data_point)

# Reshape the new data for LSTM input
new_data_reshaped = np.reshape(
    new_data_scaled, (1, 1, new_data_scaled.shape[1]))

# Make prediction using the loaded model
prediction = loaded_model.predict(new_data_reshaped)

# Decode the predicted label
predicted_label = label_encoder.inverse_transform([np.argmax(prediction)])

print("Predicted Crop (using loaded model):", predicted_label[0])
# Out:
# 1/1 [==============================] - 1s 713ms/step
# Predicted Crop (using loaded model): muskmelon

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import LSTM, Dense
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('Crop_recommendation.csv')

# Extract features and labels
features = data.iloc[:, :-1].values
labels = data.iloc[:, -1].values

# Use LabelEncoder to convert string labels to numerical labels
label_encoder = LabelEncoder()
labels_encoded = label_encoder.fit_transform(labels)

# Normalize features
scaler = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler on the training features
features_scaled = scaler.fit_transform(features)
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    features_scaled, labels_encoded, test_size=0.2, random_state=42)

# Reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# Build LSTM Model
model = Sequential()
model.add(LSTM(units=50, return_sequences=True,
          input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(LSTM(units=50))
model.add(Dense(units=len(np.unique(labels)), activation='softmax'))

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, epochs=50, batch_size=32,
                    validation_data=(X_test, y_test))


# Example new data point for prediction with 6 features
# Replace with your actual values
new_data_point = np.array([[80, 50, 42, 22.5, 75.0, 6.8, 3]])

# Normalize the new data using the fitted scaler
new_data_scaled = scaler.transform(new_data_point)

# Reshape the new data for LSTM input
new_data_reshaped = np.reshape(
    new_data_scaled, (1, 1, new_data_scaled.shape[1]))

# Make prediction
prediction = model.predict(new_data_reshaped)

# Decode the predicted label
predicted_label = label_encoder.inverse_transform([np.argmax(prediction)])

print("Predicted Crop:", predicted_label[0])
# Out:
# Epoch 1/50
# 55/55 [==============================] - 4s 18ms/step - loss: 3.0852 - accuracy: 0.0915 - val_loss: 3.0747 - val_accuracy: 0.1341
# Epoch 2/50
# 55/55 [==============================] - 0s 3ms/step - loss: 3.0295 - accuracy: 0.0835 - val_loss: 2.9441 - val_accuracy: 0.0795
# Epoch 3/50
# 55/55 [==============================] - 0s 3ms/step - loss: 2.7013 - accuracy: 0.1824 - val_loss: 2.4459 - val_accuracy: 0.2977
# Epoch 4/50
# 55/55 [==============================] - 0s 3ms/step - loss: 2.0268 - accuracy: 0.5750 - val_loss: 1.6704 - val_accuracy: 0.6386
# Epoch 5/50
# 55/55 [==============================] - 0s 3ms/step - loss: 1.3778 - accuracy: 0.7000 - val_loss: 1.2190 - val_accuracy: 0.7000
# Epoch 6/50
# 55/55 [==============================] - 0s 3ms/step - loss: 1.0299 - accuracy: 0.7852 - val_loss: 0.9553 - val_accuracy: 0.8159
# Epoch 7/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.8253 - accuracy: 0.8557 - val_loss: 0.7950 - val_accuracy: 0.8545
# Epoch 8/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.6898 - accuracy: 0.8767 - val_loss: 0.6839 - val_accuracy: 0.8727
# Epoch 9/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.5949 - accuracy: 0.8932 - val_loss: 0.6064 - val_accuracy: 0.8682
# Epoch 10/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.5257 - accuracy: 0.9074 - val_loss: 0.5495 - val_accuracy: 0.8705
# Epoch 11/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.4656 - accuracy: 0.9170 - val_loss: 0.4900 - val_accuracy: 0.8932
# Epoch 12/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.4239 - accuracy: 0.9148 - val_loss: 0.4459 - val_accuracy: 0.8909
# Epoch 13/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.3827 - accuracy: 0.9261 - val_loss: 0.4142 - val_accuracy: 0.9091
# Epoch 14/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.3521 - accuracy: 0.9312 - val_loss: 0.3813 - val_accuracy: 0.9091
# Epoch 15/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.3258 - accuracy: 0.9335 - val_loss: 0.3518 - val_accuracy: 0.9273
# Epoch 16/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.2994 - accuracy: 0.9398 - val_loss: 0.3351 - val_accuracy: 0.9182
# Epoch 17/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.2809 - accuracy: 0.9466 - val_loss: 0.3133 - val_accuracy: 0.9205
# Epoch 18/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.2616 - accuracy: 0.9477 - val_loss: 0.2935 - val_accuracy: 0.9295
# Epoch 19/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.2465 - accuracy: 0.9472 - val_loss: 0.2799 - val_accuracy: 0.9341
# Epoch 20/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.2324 - accuracy: 0.9511 - val_loss: 0.2644 - val_accuracy: 0.9341
# Epoch 21/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.2155 - accuracy: 0.9557 - val_loss: 0.2588 - val_accuracy: 0.9364
# Epoch 22/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.2037 - accuracy: 0.9574 - val_loss: 0.2424 - val_accuracy: 0.9341
# Epoch 23/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1919 - accuracy: 0.9625 - val_loss: 0.2331 - val_accuracy: 0.9432
# Epoch 24/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1865 - accuracy: 0.9619 - val_loss: 0.2250 - val_accuracy: 0.9386
# Epoch 25/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1740 - accuracy: 0.9648 - val_loss: 0.2151 - val_accuracy: 0.9455
# Epoch 26/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1661 - accuracy: 0.9665 - val_loss: 0.2048 - val_accuracy: 0.9432
# Epoch 27/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1585 - accuracy: 0.9670 - val_loss: 0.1991 - val_accuracy: 0.9455
# Epoch 28/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1507 - accuracy: 0.9710 - val_loss: 0.2042 - val_accuracy: 0.9364
# Epoch 29/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1446 - accuracy: 0.9682 - val_loss: 0.1870 - val_accuracy: 0.9477
# Epoch 30/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1380 - accuracy: 0.9722 - val_loss: 0.1880 - val_accuracy: 0.9432
# Epoch 31/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1334 - accuracy: 0.9716 - val_loss: 0.1754 - val_accuracy: 0.9500
# Epoch 32/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1305 - accuracy: 0.9710 - val_loss: 0.1746 - val_accuracy: 0.9477
# Epoch 33/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1237 - accuracy: 0.9744 - val_loss: 0.1680 - val_accuracy: 0.9545
# Epoch 34/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1179 - accuracy: 0.9778 - val_loss: 0.1641 - val_accuracy: 0.9545
# Epoch 35/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1138 - accuracy: 0.9773 - val_loss: 0.1672 - val_accuracy: 0.9591
# Epoch 36/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1109 - accuracy: 0.9784 - val_loss: 0.1649 - val_accuracy: 0.9500
# Epoch 37/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.1058 - accuracy: 0.9812 - val_loss: 0.1557 - val_accuracy: 0.9523
# Epoch 38/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1034 - accuracy: 0.9801 - val_loss: 0.1613 - val_accuracy: 0.9523
# Epoch 39/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.1023 - accuracy: 0.9761 - val_loss: 0.1505 - val_accuracy: 0.9545
# Epoch 40/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0978 - accuracy: 0.9790 - val_loss: 0.1435 - val_accuracy: 0.9591
# Epoch 41/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0952 - accuracy: 0.9795 - val_loss: 0.1469 - val_accuracy: 0.9568
# Epoch 42/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0931 - accuracy: 0.9790 - val_loss: 0.1431 - val_accuracy: 0.9545
# Epoch 43/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0893 - accuracy: 0.9801 - val_loss: 0.1431 - val_accuracy: 0.9568
# Epoch 44/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0879 - accuracy: 0.9818 - val_loss: 0.1461 - val_accuracy: 0.9545
# Epoch 45/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0848 - accuracy: 0.9773 - val_loss: 0.1403 - val_accuracy: 0.9614
# Epoch 46/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0852 - accuracy: 0.9807 - val_loss: 0.1343 - val_accuracy: 0.9591
# Epoch 47/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0826 - accuracy: 0.9801 - val_loss: 0.1307 - val_accuracy: 0.9614
# Epoch 48/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0811 - accuracy: 0.9807 - val_loss: 0.1345 - val_accuracy: 0.9568
# Epoch 49/50
# 55/55 [==============================] - 0s 4ms/step - loss: 0.0796 - accuracy: 0.9812 - val_loss: 0.1244 - val_accuracy: 0.9636
# Epoch 50/50
# 55/55 [==============================] - 0s 3ms/step - loss: 0.0777 - accuracy: 0.9818 - val_loss: 0.1214 - val_accuracy: 0.9659
# 1/1 [==============================] - 1s 727ms/step
# Predicted Crop: muskmelon
